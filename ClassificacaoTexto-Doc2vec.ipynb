# %% [markdown]
# ## Classificação de Documentos com doc2Vec
#
#
# Doc2vec é um algoritmo não supervisionado para gerar vetores para frases, parágrafos ou documentos (Representações distribuídas de sentenças e documento). Trata-se de um conceito que foi apresentado em 2014 por Le & Mikilov, veja neste [artigo](https://arxiv.org/abs/1405.4053). Este algoritmo é uma adaptação do word2vec, sendo que os vetores gerados pelo doc2vec podem ser usados para tarefas como encontrar semelhanças entre sentenças , parágrafos ou documentos.
#
# Um vetor de documento é uma representação abstrata de comprimento variável do significado contextual de um determinado tipo de documento. Assim como um vetor de palavras, é o produto do processo de treinamento para uma rede neural, onde a entrada é tipicamente um termo one-hot encoded codificado a partir do vocabulário do modelo e a saída é uma distribuição de probabilidade para palavras na próxima janela de contexto.
#
#
# Neste mini-projeto utilizaremos o conjunto de dados da BBC [dataset](http://mlg.ucd.ie/datasets/bbc.html). Este conjunto de dados é composto de 2225 documentos do site de notícias da BBC correspondendo a histórias em cinco áreas distintas: (negócios, entretenimento, política, esporte, tecnologia).
#
#
# ## Dataset
#
# Para essa tarefa, usaremos um conjunto de arquivos de texto já organizado. Este conjunto de dados é composto de 2225 documentos que correspondem a artigos de notícias da BBC, representando 5 tópicos distintos:
#
#     * Negócios
#     * Entretenimento
#     * Política
#     * Esportes
#     * Tecnologia
#
# Um exemplo de documento da categoria Tecnologia:
#
# 'UK net users leading TV downloads British TV viewers lead the trend of illegally downloading US shows from the net, according to research. New episodes of 24, Desperate Housewives and Six Feet Under, appear on the web hours after they are shown in the US, said a report. Web tracking company Envisional said 18% of downloaders were from within the UK and that downloads of TV programmers had increased by 150% in the last year....'
#
# Usaremos 250 documentos de cada categoria. Nosso vocabulário será de tamanho 25.000. Além disso, cada documento será representado por uma tag - para fins de visualização. Por exemplo, o 50º documento da seção Entretenimento será representado como entretenimento-50. Deve-se notar que este é um conjunto de dados muito pequeno comparado ao grande corpora de texto que está sendo analisado em aplicações do mundo real. No entanto, este pequeno exemplo é adequado no momento para ver o poder das Word embeddings.

# %% [markdown]
# Usaremos a seguinte estratégia:
#
# 1. Extrair os dados de todos os arquivos de texto e aprender as word embeddings.
# 2. Extrair conjuntos randômicos de documentos dos word embeddings já treinados.
# 3. Preparar os dados para os modelos de treinamento e avaliação doc2Vec
# 4. Contruir o vocabulário através de um modelo doc2vec - Distributed Bag of Words (DBOW)
# 5. Aplicar um modelo de Regressão Logística para classificação dos documentos

# %%
import csv
from sklearn.metrics import classification_report
from itertools import islice, chain
import os
import numpy as np
import nltk
from nltk.corpus import stopwords
import collections
from IPython.display import Image
import random
import zipfile
from nltk.stem import SnowballStemmer
from string import punctuation
import spacy
import seaborn as sns
import matplotlib.pyplot as plt
from gensim.models.doc2vec import TaggedDocument
from gensim.models import Doc2Vec
from tqdm import tqdm
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn import utils
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
# %matplotlib inline

# %%
url = 'http://mlg.ucd.ie/files/datasets/'

def maybe_download(filename, expected_bytes):
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Encontrado e verificado %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Não foi possível verificar o arquivo ' + filename + '. Você pode fazer o donwload via browser?')
    return filename

filename = maybe_download('bbc-fulltext.zip', 2874078)
# Out:
# Encontrado e verificado bbc-fulltext.zip

# %% [markdown]
# ## Lendo os dados com pré-processamento utilizando a biblioteca NLTK
#
# Efetua a leitura dos dados, depois converte o texto para letras minúscula e o converte em tokens usando a biblioteca nltk. Temos duas funções `read_data`, que lê `files_to_read_for_topic` de cada tópico e `read_test_data`, que separa 20 documentos de cada tópicos para fins de teste.

# %%
def read_data(filename):
    """
      Extrai artigos até um determinado limite em um arquivo zip como uma lista de palavras
      e pré-processa usando a biblioteca nltk python
      """
    data = [[],[]]
    train_data = {}
    files_to_read_for_topic = 250
    topics = ['business','entertainment','politics','sport','tech']
    with zipfile.ZipFile(filename) as z:
        parent_dir = z.namelist()[0]
        for t in topics:
            print('\tConcluída a leitura de dados para o tópico: ', t)
            for fi in range(1,files_to_read_for_topic):
                with z.open(parent_dir + t + '/'+ format(fi,'03d')+'.txt') as f:
                    file_string = f.read().decode('latin-1')
                    file_string = file_string.lower()
                    file_string = nltk.word_tokenize(file_string)
                    # Atribui a classe aos arquivos
                    data[0].append(file_string)
                    data[1].append(t)
                    """ Atribui o tópico ao documento """
                    train_data[t+'-'+str(fi)] = file_string
               
    return data, train_data

def read_test_data(filename):
    """
    Extrai artigos até um determinado limite em um arquivo zip como uma lista de palavras
    e pré-processa usando a biblioteca nltk python
    """
    test_data = {}
    files_to_read_for_topic = 350
    topics = ['business','entertainment','politics','sport','tech']
    with zipfile.ZipFile(filename) as z:
        parent_dir = z.namelist()[0]
        for t in topics:
            print('\tConcluída a leitura de dados para o tópico: ',t)            
            for fi in np.random.randint(1,files_to_read_for_topic,(73)).tolist():
                with z.open(parent_dir + t + '/'+ format(fi,'03d')+'.txt') as f:
                    file_string = f.read().decode('latin-1')
                    file_string = file_string.lower()
                    file_string = nltk.word_tokenize(file_string) 
                    """ Atribui o tópico ao documento """
                    test_data[t+'-'+str(fi)] = file_string
                
    return test_data

print('Processando dados de treinamento...\n')
words, train_words = read_data(filename)
"""
  Como os documentos estão organizados por tópicos, decidi aplicar um "shuffle", para forçar que o dicionário seja montado 
  contendo os tópicos de forma aleatória, assegurando que não haja nenhum tipo de "vício" na construção do modelo.
"""
list_train_words = list(map(tuple, train_words.items()))
random.shuffle(list_train_words)
train_words = dict(list_train_words)

print('\nProcessando dados de teste...\n')

test_words = read_test_data(filename)

list_test_words = list(map(tuple, test_words.items()))
random.shuffle(list_test_words)
test_words = dict(list_test_words)
# Out:
# Processando dados de treinamento...
#
# 	Concluída a leitura de dados para o tópico:  business
# 	Concluída a leitura de dados para o tópico:  entertainment
# 	Concluída a leitura de dados para o tópico:  politics
# 	Concluída a leitura de dados para o tópico:  sport
# 	Concluída a leitura de dados para o tópico:  tech
#
# Processando dados de teste...
#
# 	Concluída a leitura de dados para o tópico:  business
# 	Concluída a leitura de dados para o tópico:  entertainment
# 	Concluída a leitura de dados para o tópico:  politics
# 	Concluída a leitura de dados para o tópico:  sport
# 	Concluída a leitura de dados para o tópico:  tech

# %% [markdown]
# ## Construindo os Dicionários
# Para entender cada um desses elementos, vamos também assumir o texto "Eu gosto de ir à escola"
#
# * `dictionary`: mapeia uma palavra para um ID (i.e. {Eu:0, gosto:1, de:2, ir:3, à:4, escola:5})
# * `reverse_dictionary`: mapeia um ID para uma palavra (i.e. {0:Eu, 1:gosto, 2:de, 3:ir, 4:à, 5:escola}
# * `count`: Lista de elementos (palavra, frequência) (i.e. [(Eu,1),(gosto,1),(de,2),(ir,1),(à,1),(escola,1)]
# * `data` : Contém a string de texto que lemos, onde palavras são substituídas por IDs de palavras (i.e. [0, 1, 2, 3, 2, 4])
#
# Também introduzimos um token especial adicional chamado `UNK` para indicar que palavras raras são muito raras para serem usadas.

# %%
vocabulary_size = 25000
Words = []
def build_dataset(words):
    for word in words[0]:
        Words.extend(word)    
    count = [['UNK', -1]]
    count.extend(collections.Counter(Words).most_common(vocabulary_size - 1))

    # Dicionário
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    
    data = list()
    unk_count = 0
    
    for word in Words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']            
            unk_count = unk_count + 1
            
        data.append(word)

    count[0][1] = unk_count
    
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    assert len(dictionary) == vocabulary_size

    return data, count, dictionary, reverse_dictionary

def build_dataset_with_existing_dictionary(words, dictionary):
    '''
    Aqui usamos essa função para converter strings de palavras em IDs com um determinado dicionário
    '''
    data = list()
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
        data.append(word)
    return data

# Processando dados de treino
data, count, dictionary, reverse_dictionary = build_dataset(words)

train_data = {}

for k,v in train_words.items():
    print('Construindo o dataset de teste para o documento ', k)
    train_data[k] = build_dataset_with_existing_dictionary(train_words[k],dictionary)

# Processando dados de teste

test_data = {}

for k,v in test_words.items():
    print('Construindo o dataset de teste para o documento ', k)
    test_data[k] = build_dataset_with_existing_dictionary(test_words[k],dictionary)
    
print('\nPalavras mais comuns (+UNK)', count[:5])
print('\nAmostra de dados', data[:10])
print('\nChaves: ', test_data.keys())
print('\nItems: ', test_data.items())

# Removemos para liberar memória no computador. Não precisamos mais desses objetos.
del words  
#del test_words
# Out:
# Construindo o dataset de teste para o documento  politics-65
# Construindo o dataset de teste para o documento  business-200
# Construindo o dataset de teste para o documento  sport-75
# Construindo o dataset de teste para o documento  entertainment-221
# Construindo o dataset de teste para o documento  business-57
# Construindo o dataset de teste para o documento  politics-12
# Construindo o dataset de teste para o documento  entertainment-194
# Construindo o dataset de teste para o documento  sport-218
# Construindo o dataset de teste para o documento  politics-57
# Construindo o dataset de teste para o documento  entertainment-121
# Construindo o dataset de teste para o documento  entertainment-40
# Construindo o dataset de teste para o documento  tech-86
# Construindo o dataset de teste para o documento  politics-68
# Construindo o dataset de teste para o documento  entertainment-66
# Construindo o dataset de teste para o documento  politics-213
# Construindo o dataset de teste para o documento  sport-109
# Construindo o dataset de teste para o documento  sport-138
# Construindo o dataset de teste para o documento  entertainment-33
# Construindo o dataset de teste para o documento  business-192
# Construindo o dataset de teste para o documento  politics-127
# Construindo o dataset de teste para o documento  business-133
# Construindo o dataset de teste para o documento  tech-217
# Construindo o dataset de teste para o documento  politics-242
# Construindo o dataset de teste para o documento  business-169
# Construindo o dataset de teste para o documento  tech-190
# Construindo o dataset de teste para o documento  politics-22
# Construindo o dataset de teste para o documento  business-68
# Construindo o dataset de teste para o documento  politics-44
# Construindo o dataset de teste para o documento  sport-118
# Construindo o dataset de teste para o documento  politics-217
# Construindo o dataset de teste para o documento  business-105
# Construindo o dataset de teste para o documento  business-66
# Construindo o dataset de teste para o documento  politics-145
# Construindo o dataset de teste para o documento  tech-185
# Construindo o dataset de teste para o documento  entertainment-249
# Construindo o dataset de teste para o documento  entertainment-101
# Construindo o dataset de teste para o documento  tech-138
# Construindo o dataset de teste para o documento  business-171
# Construindo o dataset de teste para o documento  politics-155
# Construindo o dataset de teste para o documento  business-207
# Construindo o dataset de teste para o documento  entertainment-228
# Construindo o dataset de teste para o documento  politics-246
# Construindo o dataset de teste para o documento  tech-19
# Construindo o dataset de teste para o documento  business-91
# Construindo o dataset de teste para o documento  politics-124
# Construindo o dataset de teste para o documento  politics-216
# Construindo o dataset de teste para o documento  sport-183
# Construindo o dataset de teste para o documento  entertainment-132
# Construindo o dataset de teste para o documento  tech-26
# Construindo o dataset de teste para o documento  business-181
# Construindo o dataset de teste para o documento  tech-146
# Construindo o dataset de teste para o documento  tech-65
# Construindo o dataset de teste para o documento  politics-206
# Construindo o dataset de teste para o documento  entertainment-67
# Construindo o dataset de teste para o documento  entertainment-2
# Construindo o dataset de teste para o documento  sport-123
# Construindo o dataset de teste para o documento  tech-64
# Construindo o dataset de teste para o documento  sport-45
# Construindo o dataset de teste para o documento  tech-29
# Construindo o dataset de teste para o documento  politics-73
# Construindo o dataset de teste para o documento  politics-228
# Construindo o dataset de teste para o documento  business-93
# Construindo o dataset de teste para o documento  entertainment-35
# Construindo o dataset de teste para o documento  business-180
# Construindo o dataset de teste para o documento  tech-195
# Construindo o dataset de teste para o documento  politics-158
# Construindo o dataset de teste para o documento  politics-240
# Construindo o dataset de teste para o documento  entertainment-224
# Construindo o dataset de teste para o documento  politics-183
# Construindo o dataset de teste para o documento  business-242
# Construindo o dataset de teste para o documento  politics-62
# Construindo o dataset de teste para o documento  entertainment-232
# Construindo o dataset de teste para o documento  sport-42
# Construindo o dataset de teste para o documento  sport-48
# Construindo o dataset de teste para o documento  sport-234
# Construindo o dataset de teste para o documento  entertainment-63
# Construindo o dataset de teste para o documento  entertainment-114
# Construindo o dataset de teste para o documento  sport-74
# Construindo o dataset de teste para o documento  entertainment-205
# Construindo o dataset de teste para o documento  entertainment-77
# Construindo o dataset de teste para o documento  entertainment-92
# Construindo o dataset de teste para o documento  business-19
# Construindo o dataset de teste para o documento  entertainment-193
# Construindo o dataset de teste para o documento  tech-73
# Construindo o dataset de teste para o documento  business-74
# Construindo o dataset de teste para o documento  politics-75
# Construindo o dataset de teste para o documento  entertainment-86
# Construindo o dataset de teste para o documento  politics-109
# Construindo o dataset de teste para o documento  tech-147
# Construindo o dataset de teste para o documento  tech-109
# Construindo o dataset de teste para o documento  tech-247
# Construindo o dataset de teste para o documento  tech-206
# Construindo o dataset de teste para o documento  tech-14
# Construindo o dataset de teste para o documento  sport-189
# Construindo o dataset de teste para o documento  entertainment-147
# Construindo o dataset de teste para o documento  sport-103
# Construindo o dataset de teste para o documento  business-75
# Construindo o dataset de teste para o documento  business-116
# Construindo o dataset de teste para o documento  politics-64
# Construindo o dataset de teste para o documento  sport-245
# Construindo o dataset de teste para o documento  entertainment-168
# Construindo o dataset de teste para o documento  business-7
# Construindo o dataset de teste para o documento  politics-195
# Construindo o dataset de teste para o documento  politics-243
# Construindo o dataset de teste para o documento  sport-61
# Construindo o dataset de teste para o documento  business-82
# Construindo o dataset de teste para o documento  business-28
# Construindo o dataset de teste para o documento  politics-186
# Construindo o dataset de teste para o documento  politics-176
# Construindo o dataset de teste para o documento  sport-41
# Construindo o dataset de teste para o documento  business-89
# Construindo o dataset de teste para o documento  business-157
# Construindo o dataset de teste para o documento  tech-198
# Construindo o dataset de teste para o documento  entertainment-246
# Construindo o dataset de teste para o documento  business-62
# Construindo o dataset de teste para o documento  politics-88
# Construindo o dataset de teste para o documento  business-174
# Construindo o dataset de teste para o documento  sport-200
# Construindo o dataset de teste para o documento  tech-196
# Construindo o dataset de teste para o documento  sport-239
# Construindo o dataset de teste para o documento  entertainment-32
# Construindo o dataset de teste para o documento  entertainment-182
# Construindo o dataset de teste para o documento  politics-152
# Construindo o dataset de teste para o documento  sport-53
# Construindo o dataset de teste para o documento  tech-241
# Construindo o dataset de teste para o documento  business-109
# Construindo o dataset de teste para o documento  tech-100
# Construindo o dataset de teste para o documento  entertainment-176
# Construindo o dataset de teste para o documento  entertainment-129
# Construindo o dataset de teste para o documento  sport-160
# Construindo o dataset de teste para o documento  business-153
# Construindo o dataset de teste para o documento  sport-20
# Construindo o dataset de teste para o documento  tech-85
# Construindo o dataset de teste para o documento  tech-110
# Construindo o dataset de teste para o documento  business-110
# Construindo o dataset de teste para o documento  entertainment-210
# Construindo o dataset de teste para o documento  politics-226
# Construindo o dataset de teste para o documento  business-118
# Construindo o dataset de teste para o documento  tech-28
# Construindo o dataset de teste para o documento  tech-244
# Construindo o dataset de teste para o documento  entertainment-131
# Construindo o dataset de teste para o documento  politics-115
# Construindo o dataset de teste para o documento  tech-41
# Construindo o dataset de teste para o documento  sport-140
# Construindo o dataset de teste para o documento  entertainment-112
# Construindo o dataset de teste para o documento  tech-194
# Construindo o dataset de teste para o documento  sport-70
# Construindo o dataset de teste para o documento  business-70
# Construindo o dataset de teste para o documento  sport-219
# Construindo o dataset de teste para o documento  tech-141
# Construindo o dataset de teste para o documento  politics-237
# Construindo o dataset de teste para o documento  tech-152
# Construindo o dataset de teste para o documento  politics-236
# Construindo o dataset de teste para o documento  entertainment-47
# Construindo o dataset de teste para o documento  business-158
# Construindo o dataset de teste para o documento  business-54
# Construindo o dataset de teste para o documento  entertainment-53
# Construindo o dataset de teste para o documento  politics-193
# Construindo o dataset de teste para o documento  business-25
# Construindo o dataset de teste para o documento  business-102
# Construindo o dataset de teste para o documento  business-208
# Construindo o dataset de teste para o documento  sport-14
# Construindo o dataset de teste para o documento  entertainment-83
# Construindo o dataset de teste para o documento  politics-93
# Construindo o dataset de teste para o documento  sport-130
# Construindo o dataset de teste para o documento  politics-8
# Construindo o dataset de teste para o documento  business-202
# Construindo o dataset de teste para o documento  politics-20
# Construindo o dataset de teste para o documento  sport-8
# Construindo o dataset de teste para o documento  business-18
# Construindo o dataset de teste para o documento  sport-29
# Construindo o dataset de teste para o documento  tech-220
# Construindo o dataset de teste para o documento  sport-37
# Construindo o dataset de teste para o documento  politics-175
# Construindo o dataset de teste para o documento  entertainment-85
# Construindo o dataset de teste para o documento  politics-139
# Construindo o dataset de teste para o documento  tech-112
# Construindo o dataset de teste para o documento  sport-92
# Construindo o dataset de teste para o documento  politics-117
# Construindo o dataset de teste para o documento  entertainment-143
# Construindo o dataset de teste para o documento  politics-147
# Construindo o dataset de teste para o documento  politics-79
# Construindo o dataset de teste para o documento  politics-82
# Construindo o dataset de teste para o documento  tech-83
# Construindo o dataset de teste para o documento  tech-213
# Construindo o dataset de teste para o documento  tech-22
# Construindo o dataset de teste para o documento  sport-142
# Construindo o dataset de teste para o documento  sport-131
# Construindo o dataset de teste para o documento  entertainment-188
# Construindo o dataset de teste para o documento  tech-214
# Construindo o dataset de teste para o documento  tech-193
# Construindo o dataset de teste para o documento  business-114
# Construindo o dataset de teste para o documento  entertainment-68
# Construindo o dataset de teste para o documento  politics-233
# Construindo o dataset de teste para o documento  tech-34
# Construindo o dataset de teste para o documento  entertainment-113
# Construindo o dataset de teste para o documento  business-65
# Construindo o dataset de teste para o documento  entertainment-139
# Construindo o dataset de teste para o documento  business-136
# Construindo o dataset de teste para o documento  entertainment-245
# Construindo o dataset de teste para o documento  business-126
# Construindo o dataset de teste para o documento  business-79
# Construindo o dataset de teste para o documento  tech-115
# Construindo o dataset de teste para o documento  business-184
# Construindo o dataset de teste para o documento  business-69
# Construindo o dataset de teste para o documento  politics-101
# Construindo o dataset de teste para o documento  business-90
# Construindo o dataset de teste para o documento  business-11
# Construindo o dataset de teste para o documento  sport-120
# Construindo o dataset de teste para o documento  politics-69
# Construindo o dataset de teste para o documento  tech-24
# Construindo o dataset de teste para o documento  politics-86
# Construindo o dataset de teste para o documento  politics-7
# Construindo o dataset de teste para o documento  sport-243
# Construindo o dataset de teste para o documento  tech-176
# Construindo o dataset de teste para o documento  business-73
# Construindo o dataset de teste para o documento  sport-241
# Construindo o dataset de teste para o documento  business-188
# Construindo o dataset de teste para o documento  tech-127
# Construindo o dataset de teste para o documento  business-220
# Construindo o dataset de teste para o documento  tech-218
# Construindo o dataset de teste para o documento  sport-171
# Construindo o dataset de teste para o documento  entertainment-191
# Construindo o dataset de teste para o documento  sport-58
# Construindo o dataset de teste para o documento  tech-122
# Construindo o dataset de teste para o documento  politics-25
# Construindo o dataset de teste para o documento  entertainment-59
# Construindo o dataset de teste para o documento  sport-227
# Construindo o dataset de teste para o documento  entertainment-145
# Construindo o dataset de teste para o documento  sport-202
# Construindo o dataset de teste para o documento  sport-230
# Construindo o dataset de teste para o documento  politics-53
# Construindo o dataset de teste para o documento  entertainment-248
# Construindo o dataset de teste para o documento  business-164
# Construindo o dataset de teste para o documento  business-8
# Construindo o dataset de teste para o documento  entertainment-87
# Construindo o dataset de teste para o documento  entertainment-170
# Construindo o dataset de teste para o documento  politics-220
# Construindo o dataset de teste para o documento  sport-154
# Construindo o dataset de teste para o documento  business-219
# Construindo o dataset de teste para o documento  entertainment-163
# Construindo o dataset de teste para o documento  business-122
# Construindo o dataset de teste para o documento  tech-129
# Construindo o dataset de teste para o documento  sport-49
# Construindo o dataset de teste para o documento  tech-128
# Construindo o dataset de teste para o documento  entertainment-58
# Construindo o dataset de teste para o documento  tech-153
# Construindo o dataset de teste para o documento  politics-83
# Construindo o dataset de teste para o documento  sport-191
# Construindo o dataset de teste para o documento  politics-225
# Construindo o dataset de teste para o documento  entertainment-227
# Construindo o dataset de teste para o documento  sport-95
# Construindo o dataset de teste para o documento  business-108
# Construindo o dataset de teste para o documento  business-244
# Construindo o dataset de teste para o documento  tech-232
# Construindo o dataset de teste para o documento  sport-161
# Construindo o dataset de teste para o documento  politics-56
# Construindo o dataset de teste para o documento  tech-35
# Construindo o dataset de teste para o documento  business-100
# Construindo o dataset de teste para o documento  entertainment-12
# Construindo o dataset de teste para o documento  politics-47
# Construindo o dataset de teste para o documento  tech-51
# Construindo o dataset de teste para o documento  entertainment-106
# Construindo o dataset de teste para o documento  entertainment-164
# Construindo o dataset de teste para o documento  sport-51
# Construindo o dataset de teste para o documento  entertainment-124
# Construindo o dataset de teste para o documento  sport-193
# Construindo o dataset de teste para o documento  business-141
# Construindo o dataset de teste para o documento  sport-162
# Construindo o dataset de teste para o documento  entertainment-26
# Construindo o dataset de teste para o documento  sport-96
# Construindo o dataset de teste para o documento  tech-174
# Construindo o dataset de teste para o documento  business-241
# Construindo o dataset de teste para o documento  entertainment-156
# Construindo o dataset de teste para o documento  sport-100
# Construindo o dataset de teste para o documento  tech-17
# Construindo o dataset de teste para o documento  business-26
# Construindo o dataset de teste para o documento  politics-119
# Construindo o dataset de teste para o documento  entertainment-44
# Construindo o dataset de teste para o documento  politics-114
# Construindo o dataset de teste para o documento  business-52
# Construindo o dataset de teste para o documento  entertainment-20
# Construindo o dataset de teste para o documento  business-43
# Construindo o dataset de teste para o documento  business-183
# Construindo o dataset de teste para o documento  entertainment-192
# Construindo o dataset de teste para o documento  entertainment-52
# Construindo o dataset de teste para o documento  business-95
# Construindo o dataset de teste para o documento  politics-137
# Construindo o dataset de teste para o documento  politics-150
# Construindo o dataset de teste para o documento  tech-234
# Construindo o dataset de teste para o documento  business-226
# Construindo o dataset de teste para o documento  politics-111
# Construindo o dataset de teste para o documento  entertainment-235
# Construindo o dataset de teste para o documento  business-63
# Construindo o dataset de teste para o documento  business-121
# Construindo o dataset de teste para o documento  business-107
# Construindo o dataset de teste para o documento  tech-136
# Construindo o dataset de teste para o documento  tech-7
# Construindo o dataset de teste para o documento  tech-90
# Construindo o dataset de teste para o documento  business-48
# Construindo o dataset de teste para o documento  politics-10
# Construindo o dataset de teste para o documento  business-1
# Construindo o dataset de teste para o documento  entertainment-102
# Construindo o dataset de teste para o documento  tech-222
# Construindo o dataset de teste para o documento  tech-20
# Construindo o dataset de teste para o documento  business-138
# Construindo o dataset de teste para o documento  entertainment-1
# Construindo o dataset de teste para o documento  politics-153
# Construindo o dataset de teste para o documento  entertainment-117
# Construindo o dataset de teste para o documento  politics-181
# Construindo o dataset de teste para o documento  politics-135
# Construindo o dataset de teste para o documento  entertainment-80
# Construindo o dataset de teste para o documento  politics-198
# Construindo o dataset de teste para o documento  politics-149
# Construindo o dataset de teste para o documento  entertainment-157
# Construindo o dataset de teste para o documento  business-247
# Construindo o dataset de teste para o documento  sport-65
# Construindo o dataset de teste para o documento  sport-39
# Construindo o dataset de teste para o documento  sport-64
# Construindo o dataset de teste para o documento  entertainment-11
# Construindo o dataset de teste para o documento  politics-188
# Construindo o dataset de teste para o documento  sport-180
# Construindo o dataset de teste para o documento  business-12
# Construindo o dataset de teste para o documento  tech-53
# Construindo o dataset de teste para o documento  business-224
# Construindo o dataset de teste para o documento  business-204
# Construindo o dataset de teste para o documento  sport-170
# Construindo o dataset de teste para o documento  business-175
# Construindo o dataset de teste para o documento  politics-125
# Construindo o dataset de teste para o documento  business-83
# Construindo o dataset de teste para o documento  sport-25
# Construindo o dataset de teste para o documento  business-233
# Construindo o dataset de teste para o documento  business-196
# Construindo o dataset de teste para o documento  entertainment-25
# Construindo o dataset de teste para o documento  tech-242
# Construindo o dataset de teste para o documento  entertainment-135
# Construindo o dataset de teste para o documento  entertainment-203
# Construindo o dataset de teste para o documento  sport-158
# Construindo o dataset de teste para o documento  business-149
# Construindo o dataset de teste para o documento  sport-87
# Construindo o dataset de teste para o documento  entertainment-97
# Construindo o dataset de teste para o documento  sport-7
# Construindo o dataset de teste para o documento  tech-45
# Construindo o dataset de teste para o documento  politics-78
# Construindo o dataset de teste para o documento  entertainment-98
# Construindo o dataset de teste para o documento  politics-104
# Construindo o dataset de teste para o documento  business-27
# Construindo o dataset de teste para o documento  sport-93
# Construindo o dataset de teste para o documento  tech-27
# Construindo o dataset de teste para o documento  business-9
# Construindo o dataset de teste para o documento  entertainment-202
# Construindo o dataset de teste para o documento  tech-189
# Construindo o dataset de teste para o documento  sport-91
# Construindo o dataset de teste para o documento  politics-19
# Construindo o dataset de teste para o documento  entertainment-94
# Construindo o dataset de teste para o documento  tech-33
# Construindo o dataset de teste para o documento  business-2
# Construindo o dataset de teste para o documento  business-152
# Construindo o dataset de teste para o documento  politics-49
# Construindo o dataset de teste para o documento  tech-92
# Construindo o dataset de teste para o documento  tech-89
# Construindo o dataset de teste para o documento  entertainment-184
# Construindo o dataset de teste para o documento  sport-208
# Construindo o dataset de teste para o documento  entertainment-162
# Construindo o dataset de teste para o documento  politics-247
# Construindo o dataset de teste para o documento  entertainment-172
# Construindo o dataset de teste para o documento  tech-243
# Construindo o dataset de teste para o documento  business-6
# Construindo o dataset de teste para o documento  politics-107
# Construindo o dataset de teste para o documento  sport-182
# Construindo o dataset de teste para o documento  politics-106
# Construindo o dataset de teste para o documento  politics-180
# Construindo o dataset de teste para o documento  entertainment-138
# Construindo o dataset de teste para o documento  tech-31
# Construindo o dataset de teste para o documento  sport-248
# Construindo o dataset de teste para o documento  politics-230
# Construindo o dataset de teste para o documento  politics-37
# Construindo o dataset de teste para o documento  business-231
# Construindo o dataset de teste para o documento  tech-203
# Construindo o dataset de teste para o documento  tech-105
# Construindo o dataset de teste para o documento  entertainment-148
# Construindo o dataset de teste para o documento  entertainment-34
# Construindo o dataset de teste para o documento  politics-171
# Construindo o dataset de teste para o documento  business-246
# Construindo o dataset de teste para o documento  sport-149
# Construindo o dataset de teste para o documento  sport-163
# Construindo o dataset de teste para o documento  politics-160
# Construindo o dataset de teste para o documento  tech-4
# Construindo o dataset de teste para o documento  entertainment-152
# Construindo o dataset de teste para o documento  tech-154
# Construindo o dataset de teste para o documento  entertainment-111
# Construindo o dataset de teste para o documento  entertainment-140
# Construindo o dataset de teste para o documento  politics-89
# Construindo o dataset de teste para o documento  sport-33
# Construindo o dataset de teste para o documento  entertainment-201
# Construindo o dataset de teste para o documento  tech-63
# Construindo o dataset de teste para o documento  sport-104
# Construindo o dataset de teste para o documento  tech-126
# Construindo o dataset de teste para o documento  sport-145
# Construindo o dataset de teste para o documento  politics-36
# Construindo o dataset de teste para o documento  tech-82
# Construindo o dataset de teste para o documento  sport-246
# Construindo o dataset de teste para o documento  business-143
# Construindo o dataset de teste para o documento  business-61
# Construindo o dataset de teste para o documento  politics-4
# Construindo o dataset de teste para o documento  business-249
# Construindo o dataset de teste para o documento  entertainment-166
# Construindo o dataset de teste para o documento  sport-177
# Construindo o dataset de teste para o documento  tech-210
# Construindo o dataset de teste para o documento  entertainment-96
# Construindo o dataset de teste para o documento  tech-158
# Construindo o dataset de teste para o documento  entertainment-175
# Construindo o dataset de teste para o documento  politics-238
# Construindo o dataset de teste para o documento  business-117
# Construindo o dataset de teste para o documento  politics-178
# Construindo o dataset de teste para o documento  entertainment-204
# Construindo o dataset de teste para o documento  business-205
# Construindo o dataset de teste para o documento  politics-2
# Construindo o dataset de teste para o documento  sport-9
# Construindo o dataset de teste para o documento  entertainment-146
# Construindo o dataset de teste para o documento  politics-21
# Construindo o dataset de teste para o documento  entertainment-13
# Construindo o dataset de teste para o documento  tech-149
# Construindo o dataset de teste para o documento  entertainment-244
# Construindo o dataset de teste para o documento  entertainment-107
# Construindo o dataset de teste para o documento  tech-3
# Construindo o dataset de teste para o documento  business-239
# Construindo o dataset de teste para o documento  sport-11
# Construindo o dataset de teste para o documento  politics-74
# Construindo o dataset de teste para o documento  politics-148
# Construindo o dataset de teste para o documento  entertainment-99
# Construindo o dataset de teste para o documento  politics-50
# Construindo o dataset de teste para o documento  business-232
# Construindo o dataset de teste para o documento  sport-79
# Construindo o dataset de teste para o documento  politics-239
# Construindo o dataset de teste para o documento  business-160
# Construindo o dataset de teste para o documento  entertainment-110
# Construindo o dataset de teste para o documento  business-120
# Construindo o dataset de teste para o documento  tech-72
# Construindo o dataset de teste para o documento  entertainment-31
# Construindo o dataset de teste para o documento  politics-51
# Construindo o dataset de teste para o documento  politics-14
# Construindo o dataset de teste para o documento  politics-84
# Construindo o dataset de teste para o documento  tech-164
# Construindo o dataset de teste para o documento  business-216
# Construindo o dataset de teste para o documento  tech-52
# Construindo o dataset de teste para o documento  entertainment-51
# Construindo o dataset de teste para o documento  business-185
# Construindo o dataset de teste para o documento  sport-40
# Construindo o dataset de teste para o documento  entertainment-118
# Construindo o dataset de teste para o documento  politics-138
# Construindo o dataset de teste para o documento  sport-71
# Construindo o dataset de teste para o documento  sport-21
# Construindo o dataset de teste para o documento  business-104
# Construindo o dataset de teste para o documento  tech-13
# Construindo o dataset de teste para o documento  tech-173
# Construindo o dataset de teste para o documento  entertainment-103
# Construindo o dataset de teste para o documento  sport-156
# Construindo o dataset de teste para o documento  business-37
# Construindo o dataset de teste para o documento  sport-186
# Construindo o dataset de teste para o documento  tech-81
# Construindo o dataset de teste para o documento  tech-192
# Construindo o dataset de teste para o documento  business-39
# Construindo o dataset de teste para o documento  tech-165
# Construindo o dataset de teste para o documento  entertainment-160
# Construindo o dataset de teste para o documento  politics-192
# Construindo o dataset de teste para o documento  business-212
# Construindo o dataset de teste para o documento  politics-90
# Construindo o dataset de teste para o documento  sport-238
# Construindo o dataset de teste para o documento  business-55
# Construindo o dataset de teste para o documento  entertainment-199
# Construindo o dataset de teste para o documento  business-113
# Construindo o dataset de teste para o documento  politics-205
# Construindo o dataset de teste para o documento  entertainment-247
# Construindo o dataset de teste para o documento  politics-33
# Construindo o dataset de teste para o documento  tech-133
# Construindo o dataset de teste para o documento  sport-125
# Construindo o dataset de teste para o documento  business-53
# Construindo o dataset de teste para o documento  politics-3
# Construindo o dataset de teste para o documento  tech-36
# Construindo o dataset de teste para o documento  politics-87
# Construindo o dataset de teste para o documento  entertainment-209
# Construindo o dataset de teste para o documento  tech-184
# Construindo o dataset de teste para o documento  tech-183
# Construindo o dataset de teste para o documento  sport-82
# Construindo o dataset de teste para o documento  tech-249
# Construindo o dataset de teste para o documento  sport-62
# Construindo o dataset de teste para o documento  entertainment-197
# Construindo o dataset de teste para o documento  entertainment-45
# Construindo o dataset de teste para o documento  sport-22
# Construindo o dataset de teste para o documento  politics-123
# Construindo o dataset de teste para o documento  entertainment-126
# Construindo o dataset de teste para o documento  sport-88
# Construindo o dataset de teste para o documento  sport-2
# Construindo o dataset de teste para o documento  business-236
# Construindo o dataset de teste para o documento  business-218
# Construindo o dataset de teste para o documento  tech-69
# Construindo o dataset de teste para o documento  politics-67
# Construindo o dataset de teste para o documento  politics-94
# Construindo o dataset de teste para o documento  business-67
# Construindo o dataset de teste para o documento  tech-104
# Construindo o dataset de teste para o documento  business-38
# Construindo o dataset de teste para o documento  politics-207
# Construindo o dataset de teste para o documento  business-190
# Construindo o dataset de teste para o documento  tech-205
# Construindo o dataset de teste para o documento  business-85
# Construindo o dataset de teste para o documento  business-145
# Construindo o dataset de teste para o documento  sport-232
# Construindo o dataset de teste para o documento  tech-224
# Construindo o dataset de teste para o documento  business-240
# Construindo o dataset de teste para o documento  politics-31
# Construindo o dataset de teste para o documento  politics-163
# Construindo o dataset de teste para o documento  business-88
# Construindo o dataset de teste para o documento  business-170
# Construindo o dataset de teste para o documento  politics-18
# Construindo o dataset de teste para o documento  business-182
# Construindo o dataset de teste para o documento  business-147
# Construindo o dataset de teste para o documento  tech-186
# Construindo o dataset de teste para o documento  business-44
# Construindo o dataset de teste para o documento  sport-1
# Construindo o dataset de teste para o documento  entertainment-56
# Construindo o dataset de teste para o documento  entertainment-41
# Construindo o dataset de teste para o documento  sport-43
# Construindo o dataset de teste para o documento  entertainment-27
# Construindo o dataset de teste para o documento  tech-44
# Construindo o dataset de teste para o documento  tech-121
# Construindo o dataset de teste para o documento  entertainment-70
# Construindo o dataset de teste para o documento  business-132
# Construindo o dataset de teste para o documento  tech-56
# Construindo o dataset de teste para o documento  sport-27
# Construindo o dataset de teste para o documento  tech-240
# Construindo o dataset de teste para o documento  politics-209
# Construindo o dataset de teste para o documento  tech-87
# Construindo o dataset de teste para o documento  tech-144
# Construindo o dataset de teste para o documento  politics-11
# Construindo o dataset de teste para o documento  tech-114
# Construindo o dataset de teste para o documento  politics-105
# Construindo o dataset de teste para o documento  business-187
# Construindo o dataset de teste para o documento  politics-223
# Construindo o dataset de teste para o documento  entertainment-155
# Construindo o dataset de teste para o documento  sport-12
# Construindo o dataset de teste para o documento  politics-77
# Construindo o dataset de teste para o documento  tech-78
# Construindo o dataset de teste para o documento  business-165
# Construindo o dataset de teste para o documento  entertainment-120
# Construindo o dataset de teste para o documento  tech-94
# Construindo o dataset de teste para o documento  entertainment-22
# Construindo o dataset de teste para o documento  sport-23
# Construindo o dataset de teste para o documento  business-64
# Construindo o dataset de teste para o documento  sport-112
# Construindo o dataset de teste para o documento  tech-130
# Construindo o dataset de teste para o documento  entertainment-212
# Construindo o dataset de teste para o documento  entertainment-218
# Construindo o dataset de teste para o documento  business-177
# Construindo o dataset de teste para o documento  tech-160
# Construindo o dataset de teste para o documento  business-14
# Construindo o dataset de teste para o documento  business-101
# Construindo o dataset de teste para o documento  politics-129
# Construindo o dataset de teste para o documento  business-127
# Construindo o dataset de teste para o documento  business-33
# Construindo o dataset de teste para o documento  business-81
# Construindo o dataset de teste para o documento  business-103
# Construindo o dataset de teste para o documento  sport-68
# Construindo o dataset de teste para o documento  entertainment-165
# Construindo o dataset de teste para o documento  tech-42
# Construindo o dataset de teste para o documento  business-161
# Construindo o dataset de teste para o documento  tech-132
# Construindo o dataset de teste para o documento  business-46
# Construindo o dataset de teste para o documento  tech-235
# Construindo o dataset de teste para o documento  entertainment-93
# Construindo o dataset de teste para o documento  business-206
# Construindo o dataset de teste para o documento  tech-211
# Construindo o dataset de teste para o documento  politics-211
# Construindo o dataset de teste para o documento  sport-128
# Construindo o dataset de teste para o documento  business-50
# Construindo o dataset de teste para o documento  politics-231
# Construindo o dataset de teste para o documento  business-162
# Construindo o dataset de teste para o documento  entertainment-23
# Construindo o dataset de teste para o documento  business-243
# Construindo o dataset de teste para o documento  business-178
# Construindo o dataset de teste para o documento  politics-182
# Construindo o dataset de teste para o documento  entertainment-100
# Construindo o dataset de teste para o documento  business-119
# Construindo o dataset de teste para o documento  politics-165
# Construindo o dataset de teste para o documento  sport-203
# Construindo o dataset de teste para o documento  tech-228
# Construindo o dataset de teste para o documento  entertainment-19
# Construindo o dataset de teste para o documento  entertainment-181
# Construindo o dataset de teste para o documento  business-248
# Construindo o dataset de teste para o documento  business-168
# Construindo o dataset de teste para o documento  business-124
# Construindo o dataset de teste para o documento  sport-38
# Construindo o dataset de teste para o documento  sport-224
# Construindo o dataset de teste para o documento  politics-110
# Construindo o dataset de teste para o documento  tech-71
# Construindo o dataset de teste para o documento  business-123
# Construindo o dataset de teste para o documento  entertainment-183
# Construindo o dataset de teste para o documento  entertainment-179
# Construindo o dataset de teste para o documento  business-35
# Construindo o dataset de teste para o documento  sport-184
# Construindo o dataset de teste para o documento  business-235
# Construindo o dataset de teste para o documento  business-186
# Construindo o dataset de teste para o documento  sport-179
# Construindo o dataset de teste para o documento  entertainment-153
# Construindo o dataset de teste para o documento  sport-50
# Construindo o dataset de teste para o documento  tech-12
# Construindo o dataset de teste para o documento  tech-202
# Construindo o dataset de teste para o documento  entertainment-89
# Construindo o dataset de teste para o documento  tech-32
# Construindo o dataset de teste para o documento  tech-212
# Construindo o dataset de teste para o documento  sport-198
# Construindo o dataset de teste para o documento  politics-63
# Construindo o dataset de teste para o documento  politics-140
# Construindo o dataset de teste para o documento  sport-127
# Construindo o dataset de teste para o documento  politics-9
# Construindo o dataset de teste para o documento  politics-72
# Construindo o dataset de teste para o documento  entertainment-239
# Construindo o dataset de teste para o documento  business-223
# Construindo o dataset de teste para o documento  business-193
# Construindo o dataset de teste para o documento  business-146
# Construindo o dataset de teste para o documento  politics-184
# Construindo o dataset de teste para o documento  entertainment-196
# Construindo o dataset de teste para o documento  tech-167
# Construindo o dataset de teste para o documento  tech-37
# Construindo o dataset de teste para o documento  business-176
# Construindo o dataset de teste para o documento  tech-187
# Construindo o dataset de teste para o documento  tech-79
# Construindo o dataset de teste para o documento  sport-6
# Construindo o dataset de teste para o documento  entertainment-123
# Construindo o dataset de teste para o documento  sport-205
# Construindo o dataset de teste para o documento  business-129
# Construindo o dataset de teste para o documento  politics-23
# Construindo o dataset de teste para o documento  business-215
# Construindo o dataset de teste para o documento  tech-171
# Construindo o dataset de teste para o documento  business-106
# Construindo o dataset de teste para o documento  tech-170
# Construindo o dataset de teste para o documento  business-137
# Construindo o dataset de teste para o documento  sport-166
# Construindo o dataset de teste para o documento  tech-49
# Construindo o dataset de teste para o documento  sport-44
# Construindo o dataset de teste para o documento  entertainment-88
# Construindo o dataset de teste para o documento  business-32
# Construindo o dataset de teste para o documento  entertainment-151
# Construindo o dataset de teste para o documento  business-16
# Construindo o dataset de teste para o documento  sport-139
# Construindo o dataset de teste para o documento  business-51
# Construindo o dataset de teste para o documento  tech-237
# Construindo o dataset de teste para o documento  sport-102
# Construindo o dataset de teste para o documento  business-194
# Construindo o dataset de teste para o documento  sport-69
# Construindo o dataset de teste para o documento  entertainment-234
# Construindo o dataset de teste para o documento  tech-75
# Construindo o dataset de teste para o documento  sport-56
# Construindo o dataset de teste para o documento  sport-187
# Construindo o dataset de teste para o documento  business-36
# Construindo o dataset de teste para o documento  politics-249
# Construindo o dataset de teste para o documento  sport-211
# Construindo o dataset de teste para o documento  business-191
# Construindo o dataset de teste para o documento  tech-236
# Construindo o dataset de teste para o documento  sport-13
# Construindo o dataset de teste para o documento  entertainment-108
# Construindo o dataset de teste para o documento  business-134
# Construindo o dataset de teste para o documento  business-139
# Construindo o dataset de teste para o documento  business-229
# Construindo o dataset de teste para o documento  sport-242
# Construindo o dataset de teste para o documento  entertainment-55
# Construindo o dataset de teste para o documento  business-221
# Construindo o dataset de teste para o documento  tech-137
# Construindo o dataset de teste para o documento  tech-76
# Construindo o dataset de teste para o documento  entertainment-130
# Construindo o dataset de teste para o documento  entertainment-5
# Construindo o dataset de teste para o documento  politics-55
# Construindo o dataset de teste para o documento  business-230
# Construindo o dataset de teste para o documento  politics-80
# Construindo o dataset de teste para o documento  tech-40
# Construindo o dataset de teste para o documento  tech-18
# Construindo o dataset de teste para o documento  politics-227
# Construindo o dataset de teste para o documento  tech-106
# Construindo o dataset de teste para o documento  sport-17
# Construindo o dataset de teste para o documento  politics-194
# Construindo o dataset de teste para o documento  tech-43
# Construindo o dataset de teste para o documento  politics-118
# Construindo o dataset de teste para o documento  entertainment-60
# Construindo o dataset de teste para o documento  business-22
# Construindo o dataset de teste para o documento  sport-19
# Construindo o dataset de teste para o documento  entertainment-14
# Construindo o dataset de teste para o documento  business-23
# Construindo o dataset de teste para o documento  politics-219
# Construindo o dataset de teste para o documento  business-140
# Construindo o dataset de teste para o documento  sport-113
# Construindo o dataset de teste para o documento  entertainment-76
# Construindo o dataset de teste para o documento  tech-238
# Construindo o dataset de teste para o documento  business-111
# Construindo o dataset de teste para o documento  sport-151
# Construindo o dataset de teste para o documento  sport-10
# Construindo o dataset de teste para o documento  politics-174
# Construindo o dataset de teste para o documento  politics-200
# Construindo o dataset de teste para o documento  tech-57
# Construindo o dataset de teste para o documento  sport-213
# Construindo o dataset de teste para o documento  entertainment-195
# Construindo o dataset de teste para o documento  entertainment-240
# Construindo o dataset de teste para o documento  sport-228
# Construindo o dataset de teste para o documento  entertainment-15
# Construindo o dataset de teste para o documento  sport-110
# Construindo o dataset de teste para o documento  business-41
# Construindo o dataset de teste para o documento  entertainment-180
# Construindo o dataset de teste para o documento  entertainment-57
# Construindo o dataset de teste para o documento  sport-83
# Construindo o dataset de teste para o documento  politics-159
# Construindo o dataset de teste para o documento  business-154
# Construindo o dataset de teste para o documento  entertainment-134
# Construindo o dataset de teste para o documento  politics-222
# Construindo o dataset de teste para o documento  business-238
# Construindo o dataset de teste para o documento  tech-150
# Construindo o dataset de teste para o documento  entertainment-159
# Construindo o dataset de teste para o documento  tech-123
# Construindo o dataset de teste para o documento  entertainment-136
# Construindo o dataset de teste para o documento  politics-121
# Construindo o dataset de teste para o documento  tech-30
# Construindo o dataset de teste para o documento  business-159
# Construindo o dataset de teste para o documento  business-151
# Construindo o dataset de teste para o documento  tech-10
# Construindo o dataset de teste para o documento  sport-136
# Construindo o dataset de teste para o documento  sport-124
# Construindo o dataset de teste para o documento  entertainment-233
# Construindo o dataset de teste para o documento  sport-115
# Construindo o dataset de teste para o documento  politics-27
# Construindo o dataset de teste para o documento  politics-35
# Construindo o dataset de teste para o documento  tech-46
# Construindo o dataset de teste para o documento  tech-197
# Construindo o dataset de teste para o documento  tech-199
# Construindo o dataset de teste para o documento  sport-72
# Construindo o dataset de teste para o documento  politics-164
# Construindo o dataset de teste para o documento  entertainment-18
# Construindo o dataset de teste para o documento  sport-5
# Construindo o dataset de teste para o documento  sport-137
# Construindo o dataset de teste para o documento  politics-168
# Construindo o dataset de teste para o documento  sport-217
# Construindo o dataset de teste para o documento  tech-39
# Construindo o dataset de teste para o documento  sport-150
# Construindo o dataset de teste para o documento  business-71
# Construindo o dataset de teste para o documento  politics-229
# Construindo o dataset de teste para o documento  sport-194
# Construindo o dataset de teste para o documento  sport-204
# Construindo o dataset de teste para o documento  tech-226
# Construindo o dataset de teste para o documento  politics-134
# Construindo o dataset de teste para o documento  sport-155
# Construindo o dataset de teste para o documento  entertainment-213
# Construindo o dataset de teste para o documento  politics-224
# Construindo o dataset de teste para o documento  entertainment-62
# Construindo o dataset de teste para o documento  tech-225
# Construindo o dataset de teste para o documento  politics-157
# Construindo o dataset de teste para o documento  politics-191
# Construindo o dataset de teste para o documento  entertainment-50
# Construindo o dataset de teste para o documento  sport-165
# Construindo o dataset de teste para o documento  sport-80
# Construindo o dataset de teste para o documento  tech-230
# Construindo o dataset de teste para o documento  business-225
# Construindo o dataset de teste para o documento  politics-97
# Construindo o dataset de teste para o documento  entertainment-238
# Construindo o dataset de teste para o documento  politics-91
# Construindo o dataset de teste para o documento  sport-210
# Construindo o dataset de teste para o documento  business-98
# Construindo o dataset de teste para o documento  entertainment-38
# Construindo o dataset de teste para o documento  entertainment-198
# Construindo o dataset de teste para o documento  entertainment-154
# Construindo o dataset de teste para o documento  politics-204
# Construindo o dataset de teste para o documento  politics-189
# Construindo o dataset de teste para o documento  business-47
# Construindo o dataset de teste para o documento  entertainment-105
# Construindo o dataset de teste para o documento  politics-95
# Construindo o dataset de teste para o documento  politics-154
# Construindo o dataset de teste para o documento  tech-107
# Construindo o dataset de teste para o documento  sport-114
# Construindo o dataset de teste para o documento  entertainment-231
# Construindo o dataset de teste para o documento  sport-63
# Construindo o dataset de teste para o documento  tech-216
# Construindo o dataset de teste para o documento  entertainment-104
# Construindo o dataset de teste para o documento  sport-84
# Construindo o dataset de teste para o documento  tech-9
# Construindo o dataset de teste para o documento  politics-108
# Construindo o dataset de teste para o documento  sport-159
# Construindo o dataset de teste para o documento  sport-76
# ...
# Construindo o dataset de teste para o documento  politics-134
# Construindo o dataset de teste para o documento  sport-148
# Construindo o dataset de teste para o documento  tech-224
# Construindo o dataset de teste para o documento  tech-239
# Construindo o dataset de teste para o documento  sport-199
# Construindo o dataset de teste para o documento  sport-51
# Construindo o dataset de teste para o documento  politics-346
# Construindo o dataset de teste para o documento  business-239
# Construindo o dataset de teste para o documento  politics-258
# Construindo o dataset de teste para o documento  sport-6
# Construindo o dataset de teste para o documento  sport-155
# Construindo o dataset de teste para o documento  tech-168
# Construindo o dataset de teste para o documento  politics-9
# Construindo o dataset de teste para o documento  sport-259
# Construindo o dataset de teste para o documento  politics-345
# Construindo o dataset de teste para o documento  tech-7
# Construindo o dataset de teste para o documento  sport-170
# Construindo o dataset de teste para o documento  politics-97
# Construindo o dataset de teste para o documento  tech-128
# Construindo o dataset de teste para o documento  tech-6
# Construindo o dataset de teste para o documento  politics-94
# Construindo o dataset de teste para o documento  sport-156
# Construindo o dataset de teste para o documento  entertainment-48
# Construindo o dataset de teste para o documento  tech-206
# Construindo o dataset de teste para o documento  sport-205
# Construindo o dataset de teste para o documento  business-229
# Construindo o dataset de teste para o documento  business-9
# Construindo o dataset de teste para o documento  politics-106
# Construindo o dataset de teste para o documento  business-290
# Construindo o dataset de teste para o documento  entertainment-179
# Construindo o dataset de teste para o documento  politics-6
# Construindo o dataset de teste para o documento  politics-177
# Construindo o dataset de teste para o documento  entertainment-264
# Construindo o dataset de teste para o documento  entertainment-95
# Construindo o dataset de teste para o documento  sport-45
# Construindo o dataset de teste para o documento  politics-98
# Construindo o dataset de teste para o documento  entertainment-234
# Construindo o dataset de teste para o documento  business-178
# Construindo o dataset de teste para o documento  entertainment-328
# Construindo o dataset de teste para o documento  tech-195
# Construindo o dataset de teste para o documento  business-189
# Construindo o dataset de teste para o documento  sport-87
# Construindo o dataset de teste para o documento  sport-8
# Construindo o dataset de teste para o documento  politics-324
# Construindo o dataset de teste para o documento  tech-66
# Construindo o dataset de teste para o documento  entertainment-318
# Construindo o dataset de teste para o documento  politics-233
# Construindo o dataset de teste para o documento  politics-63
# Construindo o dataset de teste para o documento  politics-311
# Construindo o dataset de teste para o documento  entertainment-14
# Construindo o dataset de teste para o documento  politics-199
# Construindo o dataset de teste para o documento  tech-252
# Construindo o dataset de teste para o documento  entertainment-89
# Construindo o dataset de teste para o documento  sport-346
# Construindo o dataset de teste para o documento  politics-53
# Construindo o dataset de teste para o documento  business-345
# Construindo o dataset de teste para o documento  politics-8
# Construindo o dataset de teste para o documento  tech-19
# Construindo o dataset de teste para o documento  politics-317
# Construindo o dataset de teste para o documento  sport-160
# Construindo o dataset de teste para o documento  politics-191
# Construindo o dataset de teste para o documento  tech-138
# Construindo o dataset de teste para o documento  politics-137
# Construindo o dataset de teste para o documento  tech-22
# Construindo o dataset de teste para o documento  sport-284
# Construindo o dataset de teste para o documento  politics-113
# Construindo o dataset de teste para o documento  business-24
# Construindo o dataset de teste para o documento  entertainment-121
# Construindo o dataset de teste para o documento  sport-166
# Construindo o dataset de teste para o documento  politics-111
# Construindo o dataset de teste para o documento  sport-243
# Construindo o dataset de teste para o documento  politics-59
# Construindo o dataset de teste para o documento  sport-4
# Construindo o dataset de teste para o documento  sport-154
# Construindo o dataset de teste para o documento  tech-64
# Construindo o dataset de teste para o documento  tech-294
# Construindo o dataset de teste para o documento  business-312
# Construindo o dataset de teste para o documento  entertainment-232
# Construindo o dataset de teste para o documento  tech-151
# Construindo o dataset de teste para o documento  sport-81
# Construindo o dataset de teste para o documento  entertainment-149
# Construindo o dataset de teste para o documento  entertainment-209
# Construindo o dataset de teste para o documento  business-279
# Construindo o dataset de teste para o documento  business-172
# Construindo o dataset de teste para o documento  tech-8
# Construindo o dataset de teste para o documento  entertainment-240
# Construindo o dataset de teste para o documento  sport-16
# Construindo o dataset de teste para o documento  politics-325
# Construindo o dataset de teste para o documento  business-41
# Construindo o dataset de teste para o documento  entertainment-305
# Construindo o dataset de teste para o documento  politics-27
# Construindo o dataset de teste para o documento  business-264
# Construindo o dataset de teste para o documento  sport-295
# Construindo o dataset de teste para o documento  entertainment-143
# Construindo o dataset de teste para o documento  sport-187
# Construindo o dataset de teste para o documento  business-347
# Construindo o dataset de teste para o documento  entertainment-153
# Construindo o dataset de teste para o documento  tech-332
# Construindo o dataset de teste para o documento  politics-155
# Construindo o dataset de teste para o documento  tech-139
# Construindo o dataset de teste para o documento  politics-334
# Construindo o dataset de teste para o documento  tech-35
# Construindo o dataset de teste para o documento  tech-150
# Construindo o dataset de teste para o documento  entertainment-40
# Construindo o dataset de teste para o documento  sport-198
# Construindo o dataset de teste para o documento  business-25
# Construindo o dataset de teste para o documento  tech-238
# Construindo o dataset de teste para o documento  business-35
# Construindo o dataset de teste para o documento  entertainment-278
# Construindo o dataset de teste para o documento  entertainment-223
# Construindo o dataset de teste para o documento  politics-178
# Construindo o dataset de teste para o documento  sport-308
# Construindo o dataset de teste para o documento  sport-260
# Construindo o dataset de teste para o documento  business-13
# Construindo o dataset de teste para o documento  entertainment-311
# Construindo o dataset de teste para o documento  politics-179
# Construindo o dataset de teste para o documento  entertainment-68
# Construindo o dataset de teste para o documento  business-4
# Construindo o dataset de teste para o documento  entertainment-306
# Construindo o dataset de teste para o documento  business-31
# Construindo o dataset de teste para o documento  business-292
# Construindo o dataset de teste para o documento  business-157
# Construindo o dataset de teste para o documento  business-173
# Construindo o dataset de teste para o documento  business-48
# Construindo o dataset de teste para o documento  tech-229
# Construindo o dataset de teste para o documento  politics-156
# Construindo o dataset de teste para o documento  tech-25
#
# Palavras mais comuns (+UNK) [['UNK', 907], ('the', 28312), ('.', 21345), (',', 18517), ('to', 13509)]
#
# Amostra de dados ['ad', 'sales', 'boost', 'time', 'warner', 'profit', 'quarterly', 'profits', 'at', 'us']
# Chaves:  dict_keys(['business-125', 'entertainment-131', 'business-102', 'sport-327', 'politics-138', 'politics-315', 'entertainment-126', 'tech-197', 'business-62', 'politics-241', 'politics-130', 'sport-281', 'sport-230', 'entertainment-78', 'politics-260', 'sport-190', 'entertainment-334', 'tech-268', 'business-91', 'politics-87', 'tech-324', 'sport-227', 'tech-65', 'entertainment-147', 'business-241', 'sport-28', 'entertainment-34', 'sport-159', 'tech-255', 'entertainment-104', 'sport-164', 'tech-30', 'business-242', 'entertainment-195', 'politics-110', 'business-299', 'tech-297', 'entertainment-280', 'politics-159', 'entertainment-262', 'tech-1', 'tech-214', 'tech-331', 'entertainment-85', 'business-320', 'tech-52', 'tech-56', 'business-205', 'business-94', 'business-253', 'tech-104', 'politics-256', 'politics-210', 'tech-114', 'entertainment-17', 'tech-82', 'business-208', 'tech-81', 'entertainment-174', 'entertainment-254', 'sport-349', 'entertainment-140', 'business-121', 'business-155', 'sport-104', 'entertainment-99', 'entertainment-114', 'business-120', 'tech-313', 'entertainment-44', 'sport-245', 'entertainment-158', 'tech-118', 'sport-300', 'entertainment-260', 'politics-216', 'politics-304', 'politics-306', 'sport-99', 'tech-92', 'sport-315', 'entertainment-100', 'politics-35', 'sport-149', 'tech-176', 'business-318', 'tech-140', 'tech-100', 'entertainment-243', 'politics-236', 'sport-132', 'business-276', 'tech-164', 'tech-193', 'sport-63', 'entertainment-322', 'sport-325', 'politics-26', 'tech-232', 'sport-122', 'sport-131', 'tech-109', 'entertainment-5', 'business-235', 'politics-85', 'politics-108', 'sport-319', 'tech-119', 'tech-153', 'politics-339', 'entertainment-251', 'business-27', 'politics-318', 'sport-90', 'politics-104', 'entertainment-212', 'tech-317', 'business-199', 'business-283', 'entertainment-107', 'entertainment-210', 'sport-282', 'business-215', 'business-332', 'entertainment-157', 'sport-44', 'politics-117', 'tech-225', 'entertainment-237', 'entertainment-103', 'politics-52', 'business-335', 'tech-62', 'entertainment-161', 'tech-14', 'politics-207', 'politics-3', 'sport-152', 'politics-126', 'politics-102', 'business-162', 'business-230', 'tech-83', 'tech-9', 'politics-21', 'sport-157', 'tech-29', 'sport-130', 'tech-219', 'business-249', 'politics-289', 'sport-298', 'entertainment-172', 'business-14', 'politics-270', 'business-124', 'sport-2', 'tech-342', 'business-87', 'sport-297', 'sport-11', 'entertainment-180', 'politics-133', 'business-282', 'politics-319', 'sport-70', 'tech-173', 'business-57', 'entertainment-139', 'sport-232', 'entertainment-50', 'entertainment-83', 'sport-69', 'tech-245', 'tech-254', 'sport-218', 'business-202', 'entertainment-229', 'sport-111', 'sport-17', 'tech-198', 'business-313', 'sport-176', 'tech-69', 'business-232', 'business-248', 'sport-3', 'tech-349', 'entertainment-224', 'politics-227', 'tech-244', 'business-331', 'business-17', 'tech-165', 'politics-213', 'business-316', 'sport-339', 'entertainment-177', 'sport-68', 'entertainment-207', 'entertainment-261', 'business-77', 'politics-185', 'entertainment-1', 'entertainment-189', 'business-327', 'politics-134', 'sport-148', 'tech-224', 'tech-239', 'sport-199', 'sport-51', 'politics-346', 'business-239', 'politics-258', 'sport-6', 'sport-155', 'tech-168', 'politics-9', 'sport-259', 'politics-345', 'tech-7', 'sport-170', 'politics-97', 'tech-128', 'tech-6', 'politics-94', 'sport-156', 'entertainment-48', 'tech-206', 'sport-205', 'business-229', 'business-9', 'politics-106', 'business-290', 'entertainment-179', 'politics-6', 'politics-177', 'entertainment-264', 'entertainment-95', 'sport-45', 'politics-98', 'entertainment-234', 'business-178', 'entertainment-328', 'tech-195', 'business-189', 'sport-87', 'sport-8', 'politics-324', 'tech-66', 'entertainment-318', 'politics-233', 'politics-63', 'politics-311', 'entertainment-14', 'politics-199', 'tech-252', 'entertainment-89', 'sport-346', 'politics-53', 'busine ...
# Items:  dict_items([('business-125', ['wmc', 'profits', 'up', 'amid', 'bid', 'criticism', 'australian', 'mining', 'firm', 'wmc', 'resources', 'has', 'seen', 'a', 'fivefold', 'rise', 'in', 'profits', 'while', 'continuing', 'to', 'be', 'the', 'target', 'of', 'a', 'hostile', 'takeover', 'bid', '.', 'wmc', 'said', 'it', 'made', 'net', 'profits', 'of', '1.33bn', 'australian', 'dollars', '(', '$', '1bn', ';', 'â£550m', ')', 'in', '2004', ',', 'up', 'from', 'a', '$', '246bn', 'the', 'year', 'before', '.', 'it', 'is', 'currently', 'arguing', 'against', 'an', 'offer', 'from', 'swiss', 'xstrata', ',', 'which', 'the', 'firm', 'raised', 'to', 'a', '$', '8.4bn', 'last', 'week', 'after', 'wmc', 'said', 'it', 'was', 'an', 'undervaluation', '.', 'now', 'reports', 'say', 'that', 'the', 'australian', 'government', 'is', 'against', 'the', 'deal', '.', 'trade', 'minister', 'mark', 'vaile', 'has', 'said', 'that', 'the', 'bid', 'may', 'be', '``', 'against', 'the', 'national', 'interest', "''", '.', 'mr', 'vaile', ',', 'who', 'was', 'quoted', 'in', 'the', 'australian', 'financial', 'review', ',', 'compared', 'xstrata', "'s", 'attempt', 'to', 'take', 'over', 'wmc', 'to', 'a', 'similar', 'bid', 'by', 'oil', 'giant', 'shell', 'for', 'australia', "'s", 'woodside', 'petroleum', 'in', '2001.', 'the', 'bid', 'was', 'thrown', 'out', 'by', 'treasurer', 'peter', 'costello', 'on', 'national', 'interest', 'grounds', '.', 'wmc', "'s", 'interests', 'in', 'uranium', 'deposits', 'were', 'a', 'contributing', 'factor', ',', 'mr', 'vaile', 'said', '.', 'wmc', 'itself', ',', 'however', ',', 'has', 'no', 'objection', 'in', 'principle', 'to', 'being', 'bought', 'out', ',', 'having', 'spun', 'off', 'its', 'aluminium', 'operations', 'in', '2002', 'to', 'make', 'itself', 'a', 'more', 'tempting', 'target', '-', 'as', 'long', 'as', 'the', 'price', 'is', 'right', '.', 'its', 'stellar', 'performance', 'in', '2004', 'has', 'been', 'built', 'on', 'sky-high', 'prices', 'for', 'metals', '.', 'copper', 'and', 'nickel', 'in', 'particular', 'have', 'been', 'in', 'high', 'demand', 'thanks', 'to', 'china', "'s", 'booming', 'economy', ',', 'which', 'expanded', 'more', 'than', '9', '%', 'in', 'each', 'of', 'the', 'past', 'two', 'years', '.', 'nickel', 'prices', 'rose', '43', '%', 'during', 'the', 'year', ',', 'with', 'copper', 'up', '36', '%', '.']), ('entertainment-131', ['franz', 'man', 'seeks', 'government', 'help', 'franz', 'ferdinand', 'frontman', 'alex', 'kapranos', 'has', 'called', 'for', 'more', 'government', 'help', 'for', 'musicians', ',', 'while', 'taking', 'part', 'in', 'an', 'edinburgh', 'lectures', 'discussion', '.', '``', 'for', 'any', 'cultural', 'output', 'to', 'thrive', 'there', 'needs', 'to', 'be', 'some', 'kind', 'of', 'state', 'input', 'to', 'that', 'as', 'well', ',', "''", 'he', 'said', '.', 'but', 'kapranos', 'warned', 'against', 'musicians', 'being', 'too', 'closely', 'linked', 'with', 'mps', ',', 'at', 'the', 'university', 'of', 'edinburgh', 'event', '.', '``', 'i', 'think', 'the', 'role', 'of', 'musicians', 'is', 'to', 'question', 'politicians', 'rather', 'than', 'to', 'go', 'to', 'bed', 'with', 'them', ',', "''", 'he', 'said', '.', 'kapranos', 'joined', 'the', 'prestigious', 'lecture', 'series', 'to', 'discuss', 'scotland', "'s", 'role', 'in', 'making', '21st', 'century', 'music', '.', '``', 'there', 'are', 'elements', 'of', 'our', 'musical', 'output', 'which', 'require', 'sustenance', 'because', 'they', 'are', "n't", 'self-sufficient', ',', "''", 'he', 'said', '.', '``', 'but', 'so-called', 'commercial', 'music', 'would', 'benefit', 'from', 'investment', 'as', 'well', '.', "''", 'he', 'warned', 'musicians', 'against', 'being', 'allied', 'to', 'a', 'particular', 'party', ',', 'however', '.', '``', 'i', 'do', "n't", 'know', 'if', 'having', 'tea', 'with', 'politicians', 'is', 'always', 'a', 'good', 'idea', '.', "''", 'kapranos', 'and', 'his', 'glasgow', 'four-piece', 'band', 'have', 'been', 'nominated', 'for', 'five', 'prizes', 'at', 'next', 'week', "'s", 'brit',  ...

# %% [markdown]
# ## Preparação dos dados para criação do vocabulário no doc2vec

# %%
# Converte de Dicionário para lista
data_train = [ [k,v] for k, v in train_data.items() ]
data_train = np.array(data_train)
data_test = [ [k,v] for k, v in test_data.items() ]
data_test = np.array(data_test)

# %%
# função para Identificar as classes dos documentos e preparando os dados para o algoritimo
def prepara_dados(data):
    datax = [[],[]]
    for x in range(data.shape[0]):
        s = data[x][0]
        s = s.split("-")
        datax[0].append(s[0])
        datax[1].append(data[x][1])                
    return datax

data_train = prepara_dados(data_train)
data_test = prepara_dados(data_test)

# %%
def label_sentences(corpus, topics):
    """
    A implementação do Doc2Vec da Gensim exige que cada documento / parágrafo tenha um rótulo associado a ele.
    Fiz isso usando o método TaggedDocument, etiquetando com a própria classe do documento.
    """
   
    labeled = []
    tags = np.unique(topics, return_counts=False)
    for i, v in enumerate(corpus):
        label = [s for s in tags if topics[i] in s]
        doc =  " ".join(str(x) for x in v)
        labeled.append(TaggedDocument(doc.split(), label))
    return labeled
X_train = label_sentences(np.array(data_train[1]), data_train[0])
X_test  = label_sentences(np.array(data_test[1]), data_test[0])

# %%
len(X_train)
# Out:
# 1245

# %%
len(X_test)
# Out:
# 333

# %% [markdown]
# ## Modelos de Treinamento e Avaliação doc2Vec
#
# Primeiramente instanciamos um modelo doc2vec - Distributed Bag of Words (DBOW). Na arquitetura word2vec, nós temos os algoritmos  “continuous bag of words” (CBOW) e “skip-gram” (SG), já na arquitetura doc2vec, os algoritmos correspondentes são “distributed memory” (DM) e “distributed bag of words” (DBOW).
#
# O DBOW é o modelo doc2vec análogo ao modelo Skip-gram do word2vec. Os vetores de parágrafos são obtidos pelo treinamento de uma rede neural na tarefa de prever uma distribuição de probabilidade de palavras em um parágrafo, dada uma palavra aleatoriamente amostrada do parágrafo.

# %%
Image(url = 'Doc2Vec.png')
# Out:
# <img src="Doc2Vec.png"/>

# %%
# Instanciando um modelo Doc2Vec com um vetor de 128 palavras

model_dbow = Doc2Vec(dm=0, vector_size=128, window=10, negative=5, cbow_mean=1, min_count=1, alpha=0.1, min_alpha=0.065)
model_dbow.build_vocab([x for x in tqdm(X_train)])


# Alicando 50 iterações sobre o corpus de treinamento.

for epoch in range(50):
    model_dbow.train(utils.shuffle([x for x in tqdm(X_train)]), total_examples=len(X_train), epochs=10)
    model_dbow.alpha -= 0.002
    model_dbow.min_alpha = model_dbow.alpha
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<00:00, 1250756.52it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<00:00, 811863.88it/s]
# 100%|█████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<00:00, 1247171.84it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<00:00, 107697.08it/s]
# 100%|█████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<00:00, 1247767.86it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<00:00, 127696.88it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<00:00, 1244793.44it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<00:00, 224646.53it/s]
# 100%|█████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<00:00, 1248066.08it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 1245/1245 [00:00<?, ?it/s]

# %% [markdown]
# ## Construindo os Vetores de Recurso para o Classificador

# %%
# %%time

# Dados de treino

train_targets, train_regressors = zip(
    *[(doc.tags[0], model_dbow.infer_vector(doc.words, alpha=0.1, min_alpha=0.065, epochs=100)) for doc in X_train])
# Out:
# Wall time: 46.2 s

# %%
# %%time

# Dados de teste

test_targets, test_regressors = zip(
    *[(doc.tags[0], model_dbow.infer_vector(doc.words, alpha=0.1, min_alpha=0.065, epochs=100)) for doc in X_test])
# Out:
# Wall time: 13.7 s

# %% [markdown]
# ## Treinando o Classificador de Regressão Logística.

# %%
# Aplicando de Regressão Logistica
topics = ['business','entertainment','politics','sport','tech']
logreg = LogisticRegression(n_jobs=1, C=1e5)
logreg.fit(train_regressors, train_targets)
y_pred = logreg.predict(test_regressors)
print('accuracy %s' % accuracy_score(y_pred, test_targets))
print(classification_report(test_targets, y_pred,target_names=topics))
# Out:
# accuracy 0.990990990990991
#                precision    recall  f1-score   support
#
#      business       1.00      0.98      0.99        64
# entertainment       0.97      1.00      0.99        67
#      politics       1.00      1.00      1.00        66
#         sport       0.98      0.97      0.98        67
#          tech       1.00      1.00      1.00        69
#
#   avg / total       0.99      0.99      0.99       333

# %%
test_targets
# Out:
# ('business',
#  'politics',
#  'entertainment',
#  'sport',
#  'business',
#  'sport',
#  'sport',
#  'business',
#  'politics',
#  'business',
#  'entertainment',
#  'business',
#  'business',
#  'tech',
#  'tech',
#  'sport',
#  'business',
#  'politics',
#  'tech',
#  'politics',
#  'tech',
#  'tech',
#  'entertainment',
#  'tech',
#  'tech',
#  'business',
#  'politics',
#  'sport',
#  'entertainment',
#  'entertainment',
#  'politics',
#  'sport',
#  'tech',
#  'business',
#  'politics',
#  'tech',
#  'politics',
#  'politics',
#  'tech',
#  'politics',
#  'tech',
#  'sport',
#  'business',
#  'politics',
#  'politics',
#  'business',
#  'tech',
#  'politics',
#  'business',
#  'politics',
#  'sport',
#  'tech',
#  'politics',
#  'tech',
#  'politics',
#  'entertainment',
#  'tech',
#  'sport',
#  'entertainment',
#  'business',
#  'entertainment',
#  'tech',
#  'sport',
#  'sport',
#  'tech',
#  'politics',
#  'entertainment',
#  'sport',
#  'business',
#  'entertainment',
#  'sport',
#  'sport',
#  'sport',
#  'tech',
#  'entertainment',
#  'business',
#  'entertainment',
#  'politics',
#  'entertainment',
#  'tech',
#  'entertainment',
#  'entertainment',
#  'business',
#  'tech',
#  'entertainment',
#  'sport',
#  'entertainment',
#  'entertainment',
#  'sport',
#  'entertainment',
#  'business',
#  'business',
#  'sport',
#  'politics',
#  'sport',
#  'politics',
#  'business')

# %%
len(test_targets)
# Out:
# 97

# %%
acuracia = np.sum(y_pred == test_targets) / len(test_targets)

# %%
print(acuracia)
# Out:
# 0.990990990990991

# %%
y_pred
# Out:
# array(['business', 'politics', 'entertainment', 'sport', 'business',
#        'sport', 'sport', 'business', 'politics', 'business',
#        'entertainment', 'business', 'business', 'tech', 'tech', 'sport',
#        'business', 'politics', 'tech', 'politics', 'tech', 'tech',
#        'entertainment', 'tech', 'tech', 'business', 'politics', 'sport',
#        'entertainment', 'entertainment', 'politics', 'sport', 'tech',
#        'business', 'politics', 'tech', 'politics', 'politics', 'tech',
#        'politics', 'tech', 'sport', 'business', 'politics', 'politics',
#        'business', 'tech', 'politics', 'business', 'politics', 'sport',
#        'tech', 'politics', 'tech', 'politics', 'entertainment', 'tech',
#        'sport', 'entertainment', 'business', 'entertainment', 'tech',
#        'sport', 'sport', 'tech', 'politics', 'entertainment', 'sport',
#        'business', 'entertainment', 'sport', 'sport', 'sport', 'tech',
#        'entertainment', 'business', 'entertainment', 'politics',
#        'entertainment', 'tech', 'entertainment', 'entertainment',
#        'business', 'tech', 'entertainment', 'sport', 'entertainment',
#        'entertainment', 'sport', 'entertainment', 'business', 'business',
#        'sport', 'politics', 'sport', 'politics', 'business'], dtype='<U13')

# %% [markdown]
# ## Resultado
#
# Fiquei impressionado com precisão apresentada nos dados de teste, onde este modelo atingiu uma acurácia de 0.990990990990991, demostrando que doc2vec é uma excelente ferramenta para tarefas de classificação de documentos.

# %% [markdown]
# ## Referencias
#
# [Curso de Processamento de Linguagem Natural e Reconhecimento de Voz da Formação Inteligência Artificial - Datascienceacademy](https://www.datascienceacademy.com.br)
#
# [BBC Datasets](http://mlg.ucd.ie/datasets/bbc.html)
#
# [Gemsin](https://radimrehurek.com/gensim/models/keyedvectors.html)
#
# [Distributed Representations of Words and Phrases and their Compositionality](https://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf)
#
# [Distributed Representations of Sentences and Documents](https://cs.stanford.edu/~quocle/paragraph_vector.pdf)
#
# [A gentle introduction to Doc2Vec](https://medium.com/scaleabout/a-gentle-introduction-to-doc2vec-db3e8c0cce5e)
#
# [Gensim Doc2Vec Tutorial on the IMDB Sentiment Dataset](https://github.com/RaRe-Technologies/gensim/blob/3c3506d51a2caf6b890de3b1b32a8b85f7566ca5/docs/notebooks/doc2vec-IMDB.ipynb)
#
# [Document classification with word embeddings tutorial](https://github.com/RaRe-Technologies/movie-plots-by-genre/blob/master/ipynb_with_output/Document%20classification%20with%20word%20embeddings%20tutorial%20-%20with%20output.ipynb)
